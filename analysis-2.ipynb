# %%
import pandas as pd

# %%
nsh = pd.read_csv("noteStatusHistory-00000.tsv", sep="\t", low_memory=False)
nsh
# Out:
#                       noteId  \
# 0        1352796878438424576
# 1        1353415873227177985
# 2        1354586938863443971
# 3        1354588003075764229
# 4        1354588172659920899
# ...                      ...
# 1972094  1910143308191727741
# 1972095  1910143358942810349
# 1972096  1910143498994810898
# 1972097  1910143555294888066
# 1972098  1910143634131017885
#
#                                    noteAuthorParticipantId  createdAtMillis  \
# 0        B021517F4F8F9F372DCD70BB8F8A21A80C12D7EFDE8B2F...    1611366884227
# 1        D4C9EDB464DF2D4A6D8F68CA8D1F86226B50EB9D3B0F33...    1611514464087
# 2        C0AF45F4C4B2240E7AB31456957E5D770FF7AFA13627C7...    1611793667892
# 3        9C480F7B2E882F19F9FBF75BD13FEA53031875AC42FDF6...    1611793921619
# 4        931B6CFE7C2FDF3653B0A63DC20DF3C51F8AA3BEB9D613...    1611793962051
# ...                                                    ...              ...
# ...

# %%
users = pd.read_csv("userEnrollment-00000.tsv", sep="\t", low_memory=False)
#filtering for all users who have writing capability
users = users[users['enrollmentState'] != 'newUser']
users
# Out:
#                                              participantId  \
# 2        C784F04F26E124F4D6EC01658D8F5565005D3092741FB3...
# 3        5684B38EB58FD8BE75ABA37F0BE040EC70380B002ADF9D...
# 4        1C0972F584F1BD912FB957D99A854609C93213D0A9C361...
# 6        EA43F3694910DA08DE41F0E576C99B86AC9CCE3F73ED18...
# 7        78B383AA66981F722CB82AACB24CF853937CAC0F680DDB...
# ...                                                    ...
# 1150190  7769D68C5B732ED3B91439EEEEEDD278E4A4582744CDB4...
# 1150199  82A88584B96CE4C6C388C82FDC892785487A43CA24944A...
# 1150205  5F0DD2179115FFDF75206D76A575CF79DA82B0FD52B2F6...
# 1150217  44FCAE6187912DFF7551E56B9F827B5E4D0448910160BF...
# 1150219  48FE035683FFAF90BBBEF46886FC9B48A99A78DC1DF1DD...
#
#                enrollmentState  successfulRatingNeededToEarnIn  \
# 2        earnedOutAcknowledged                              12
# 3                     earnedIn                               5
# 4                     earnedIn                               5
# ...

# %%
#total users with writing feature: 468616

# %%
#filtering users who are earned in and have current writing capability
users_filtered = users[users['enrollmentState'] != 'earnedIn']
users_filtered
# Out:
#                                              participantId  \
# 2        C784F04F26E124F4D6EC01658D8F5565005D3092741FB3...
# 31       475EC98DF9CA06A648B301AD26F8E643376BBC999EB67D...
# 70       A6E0FB341EEBD95040E4D34FD246A4E782CF24C64E0591...
# 72       4A9563FDAC6262B28D7B4009D820EE0B731BC0BA1E3307...
# 106      9E3B1EC00D25DA9C98A4E0911F7E88F59E00BD29F507AF...
# ...                                                    ...
# 1149957  A376D5E4C22067105ACD5C23C67B8E95CAF28E1A58FD3D...
# 1149962  7628B4F578732270BC67FD9024DCA996EBC88D92D01F47...
# 1150017  81A7A0D4E9E6DD5C727DE6129E22FDC6C8E706F90ACE0D...
# 1150078  5A56D2CE070C5FE050016BC20C05E71515424C105A3FF9...
# 1150154  E440DCFF5F1FDD7B577B8315595B40D53D1813E94CB539...
#
#                enrollmentState  successfulRatingNeededToEarnIn  \
# 2        earnedOutAcknowledged                              12
# 31       earnedOutAcknowledged                              21
# 70                      atRisk                               5
# ...

# %%
(44779*100)/468616
# Out:
# 9.555584956552913

# %% [markdown]
# ### 9.5% of users with writing capability have had their capabilities taken away at least once because of poor ratings, and many have been removed permanently too
